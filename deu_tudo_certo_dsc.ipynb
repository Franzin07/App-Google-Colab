# %% [markdown]
# <a href="https://colab.research.google.com/github/Franzin07/App-Google-Colab/blob/main/deu_tudo_certo_dsc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nossa rede social

# %%
# !pip install supabase
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.1/164.1 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.0 MB/s eta 0:00:00
# ...

# %%
from supabase import create_client, Client

#client (python via cli) conectando com o banco de dados (servidor)
supabase: Client = create_client('https://fgsdgevdgsbzwhtpopqz.supabase.co', 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImZnc2RnZXZkZ3NiendodHBvcHF6Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3MjM4MTA2MDIsImV4cCI6MjAzOTM4NjYwMn0._-JOZcGlPk3y3-hNadRzVDrQFs1ghors1xmIUah9VwE')

# %%
from pprint import pprint
import uuid
import os


def ListPosts():
  response = (
    supabase.table("alunos_posts")
    .select("*","bento_alunos(user_name)")
    .order("posted_at", desc=True)
    .execute()
  )
  for post in response.data:
    print(post)


def posts():
  print('----- [ Posts ] ----- ')
  print("1 - Listar Posts")
  print("2 - Criar Post")
  print("3 - Sair")

  while True:
        try:
            option = int(input('escolha opcao: '))
            break # QUEBRAR O CODIGUINHO
        except ValueError:
            print("| ERRO | Opção inválida. *Digite apenas numeros !")
  if option == 1:
    ListPosts()
    return posts()

  if option == 2:
    print("criar post")
    content = input("Digite o conteudo do post: ")
    post_id = str(uuid.uuid4())
    supabase.table("alunos_posts").insert({"id": post_id, "content": content}).execute()
    return posts()

  if option == 3:
    print("saindo")
    return exit()

def clearterminal():
  if os.name == 'Windows':
    os.system('cls')
  else:
    os.system('clear')




def cadastrer():
  print('----- [ Cadastro ] ----- \nDigite o Usuario e a senha que deseja cadastra-lo:\n')
  usernamek = input('Digite o usuario: ')
  namek = input('Digite o nome: ')
  print(f'| INFO | Usuario cadastrado com sucesso! > {usernamek}')

  password = input('Digite a senha: ')
  password_confirm = input('Confirme a senha: ')
  user_id = str(uuid.uuid4())

  if password != password_confirm:
    print('| ERRO | Senhas não sao iguais, tente novamente!\n')
    return cadastrer()

  else:
    print(f'| INFO | Senha cadastrada com sucesso! > {password}')
    response = (
      supabase.table("bento_alunos")
      .insert({"id": user_id, "user_name": usernamek, "name": namek, "password": password  })
      .execute()
    )



def trylogin():
    user_name = input('Digite o usuário: ').strip()
    password = input('Digite a senha: ').strip()

    response = (
        supabase.table("bento_alunos")
        .select("*")
        .eq("user_name", user_name)
        .execute()
    )

    # Debug: Mostra o que foi retornado do banco
    if len(response.data) == 0:
        print("Usuário não encontrado.")
        return trylogin()

    # Print para verificar a senha retornada
    print("Senha armazenada no banco:", response.data[0]['password'])

    # Verifica se a senha está correta
    if response.data[0]['password'] == password:
        clearterminal()
        print("Login realizado com sucesso!")
        return posts()
    else:
        print("Senha incorreta.")
        return trylogin()



def showmenu():
    print('---------------[ MENU ] ------------------\n')
    print('1 - cadastrar usuario')
    print('2 - login ')
    print('3 - sair')
    print('------------------------------------------\n')
    while True:
        try:
            option = int(input('escolha opcao: '))
            break # QUEBRAR O CODIGUINHO
        except ValueError:
            print("| ERRO | Opção inválida. *Digite apenas numeros !") #IF SE ELE ESCOLHER NUMERO DE OPCAO ERRADA

    if option == 1:
        cadastrer()


    elif option == 2:
        #LOGIN > LINKAR AINDA COM BD TAMBEM BOSTA
        print('----- [ Login ] ----- \nDigite o Usuario e a senha da conta:\n')
        trylogin()



    elif option == 3:
        print('saindo')
        return exit()

    elif option == 4:
        posts()
    else:
        print(f'| ERRO | opcao {option} invalida, tente outra opcao valida! (de 1 a 3)\n')
        return showmenu()

showmenu()
# Out:
# ---------------[ MENU ] ------------------
#
# 1 - cadastrar usuario
# 2 - login
# 3 - sair
# ------------------------------------------
#
# ----- [ Login ] -----
# Digite o Usuario e a senha da conta:
#
# Senha armazenada no banco: 123
# Senha incorreta.
